# %%
import pandas as pd

# %%
# Bring in Combine Data 
NFL_1999_2015_Combine_Data = pd.read_csv("Combine_Data/1999_2015_NFL_Combine_Data.csv", error_bad_lines=False)
NFL_2016_Combine_Data = pd.read_csv("Combine_Data/2016_NFL_Combine_Data.csv", error_bad_lines=False)
NFL_2017_Combine_Data = pd.read_csv("Combine_Data/2017_NFL_Combine_Data.csv", error_bad_lines=False)

# %%
# Combine Data into One Data Frame
frames = [NFL_1999_2015_Combine_Data, NFL_2016_Combine_Data, NFL_2017_Combine_Data]
combine_result = pd.concat(frames)
combine_result.head()
# Out:
#    20 Yard Shuttle  40 Yard Dash  60 Yard Shuttle  Arm Length  Bench Press  \
# 0             3.95          4.60              NaN         0.0         24.0
# 1             0.00          4.42              NaN         0.0         12.0
# 2             4.10          4.57              NaN         0.0         19.0
# 3             4.20          4.55              NaN         0.0         24.0
# 4             4.07          4.43              NaN         0.0         13.0
#
#    Broad Jump        College  Grade  Hands  Height          Player Position  \
# 0       130.0       Nebraska    5.9    0.0    69.0  Ameer Abdullah       RB
# 1         0.0            USC    5.6    0.0    72.0  Nelson Agholor       WR
# 2       121.0      Boise St.    6.0    0.0    72.0       Jay Ajayi       RB
# 3       121.0            LSU    5.4    0.0    73.0  Kwon Alexander      OLB
# 4       121.0  West Virginia    5.3    0.0    68.0    Mario Alford       WR
#
# ...

# %%
# Put Data into New CSV
result.to_csv('Totals_Data/Combine_Total_data.csv')
