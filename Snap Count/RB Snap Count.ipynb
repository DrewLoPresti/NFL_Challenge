# %%
# Bring in snap counts for each year

import pandas as pd
import numpy as np

rb12 = "../Snap Count/rb/rb2012.csv"

snap_count12 = pd.read_csv(rb12)
snap_count12.head()
# Out:
#    Rank             Name Team Position  Played  SnapsPlayed  SnapsPerGame  \
# 0     1      Andre Brown  NYG       RB      10          226          22.6
# 1     2  Adrian Peterson  MIN       RB      16          771          48.2
# 2     3       CJ Spiller  BUF       RB      16          569          35.6
# 3     4   Marshawn Lynch  SEA       RB      16          674          42.1
# 4     5    Stevan Ridley   NE       RB      16          550          34.4
#
#    SnapsPlayedPercentage  RushSnapPercentage  TargetSnapPercentage  \
# 0                   31.1                32.3                   7.5
# 1                   74.5                45.1                   6.6
# 2                   56.3                36.4                  10.0
# 3                   66.3                46.7                   4.5
# 4                   44.4                52.7                   2.5
#
#    TouchSnapPercentage  IntendedTouchSnapPercentage  FantasyPoints  \
# 0                 37.6                         39.8           97.1
# 1                 50.3                         51.8          307.4
# 2                 43.9                         46.4          212.3
# 3                 50.1                         51.2          246.6
# 4                 53.8                         55.3          199.4
#
#    FantasyPointSnapPercentage
# 0                        43.0
# 1                        39.9
# 2                        37.3
# 3                        36.6
# 4                        36.3

# %%
# Clean up dataframes

snap_count12.drop(['Rank', 'Played', 'SnapsPerGame', 'SnapsPlayedPercentage', 'RushSnapPercentage',
                   'TargetSnapPercentage', 'TouchSnapPercentage', 'IntendedTouchSnapPercentage',
                   'FantasyPoints', 'FantasyPointSnapPercentage'], axis=1, inplace=True)
snap_count12.head()
# Out:
#               Name Team Position  SnapsPlayed
# 0      Andre Brown  NYG       RB          226
# 1  Adrian Peterson  MIN       RB          771
# 2       CJ Spiller  BUF       RB          569
# 3   Marshawn Lynch  SEA       RB          674
# 4    Stevan Ridley   NE       RB          550

# %%
rb13 = "../Snap Count/rb/rb2013.csv"

snap_count13 = pd.read_csv(rb13)
snap_count13.head()
# Out:
#    Rank            Name Team Position  Played  SnapsPlayed  SnapsPerGame  \
# 0     1    Ryan Mathews  LAC       RB      16          471          29.4
# 1     2  Jamaal Charles   KC       RB      15          845          56.3
# 2     3     Edwin Baker  CLE       RB       3           97          32.3
# 3     4   Stevan Ridley   NE       RB      14          333          23.8
# 4     5  Ahmad Bradshaw  IND       RB       3          102          34.0
#
#    SnapsPlayedPercentage  RushSnapPercentage  TargetSnapPercentage  \
# 0                   42.4                60.5                   7.0
# 1                   78.3                30.7                  12.3
# 2                   51.3                44.3                   9.3
# 3                   27.8                53.5                   3.6
# 4                   29.9                40.2                   7.8
#
#    TouchSnapPercentage  IntendedTouchSnapPercentage  FantasyPoints  \
# 0                 66.0                         67.5          184.4
# 1                 38.9                         43.0          308.0
# 2                 52.6                         53.6           34.8
# 3                 56.5                         57.1          117.5
# 4                 47.1                         48.0           34.8
#
#    FantasyPointSnapPercentage
# 0                        39.2
# 1                        36.4
# 2                        35.9
# 3                        35.3
# 4                        34.1

# %%
snap_count13.drop(['Rank', 'Played', 'SnapsPerGame', 'SnapsPlayedPercentage', 'RushSnapPercentage',
                   'TargetSnapPercentage', 'TouchSnapPercentage', 'IntendedTouchSnapPercentage',
                   'FantasyPoints', 'FantasyPointSnapPercentage'], axis=1, inplace=True)
snap_count13.head()
# Out:
#              Name Team Position  SnapsPlayed
# 0    Ryan Mathews  LAC       RB          471
# 1  Jamaal Charles   KC       RB          845
# 2     Edwin Baker  CLE       RB           97
# 3   Stevan Ridley   NE       RB          333
# 4  Ahmad Bradshaw  IND       RB          102

# %%
rb14 = "../Snap Count/rb/rb2014.csv"

snap_count14 = pd.read_csv(rb14)
snap_count14.head()
# Out:
#    Rank            Name Team Position  Played  SnapsPlayed  SnapsPerGame  \
# 0     1    Arian Foster  HOU       RB      13          621          47.8
# 1     2  Marshawn Lynch  SEA       RB      16          704          44.0
# 2     3  DeMarco Murray  DAL       RB      16          783          48.9
# 3     4     Jeremy Hill  CIN       RB      16          501          31.3
# 4     5     CJ Anderson  DEN       RB      15          495          33.0
#
#    SnapsPlayedPercentage  RushSnapPercentage  TargetSnapPercentage  \
# 0                   56.0                41.9                   9.5
# 1                   66.6                39.8                   6.8
# 2                   73.9                50.2                   8.2
# 3                   47.2                44.3                   6.4
# 4                   43.9                36.2                   8.9
#
#    TouchSnapPercentage  IntendedTouchSnapPercentage  FantasyPoints  \
# 0                 48.1                         51.5          235.5
# 1                 45.0                         46.6          265.3
# 2                 57.5                         58.4          294.1
# 3                 49.7                         50.7          183.9
# 4                 43.0                         45.1          177.3
#
#    FantasyPointSnapPercentage
# 0                        37.9
# 1                        37.7
# 2                        37.6
# 3                        36.7
# 4                        35.8

# %%
snap_count14.drop(['Rank', 'Played', 'SnapsPerGame', 'SnapsPlayedPercentage', 'RushSnapPercentage',
                   'TargetSnapPercentage', 'TouchSnapPercentage', 'IntendedTouchSnapPercentage',
                   'FantasyPoints', 'FantasyPointSnapPercentage'], axis=1, inplace=True)
snap_count14.head()
# Out:
#              Name Team Position  SnapsPlayed
# 0    Arian Foster  HOU       RB          621
# 1  Marshawn Lynch  SEA       RB          704
# 2  DeMarco Murray  DAL       RB          783
# 3     Jeremy Hill  CIN       RB          501
# 4     CJ Anderson  DEN       RB          495

# %%
rb15 = "../Snap Count/rb/rb2015.csv"

snap_count15 = pd.read_csv(rb15)
snap_count15.head()
# Out:
#    Rank             Name Team Position  Played  SnapsPlayed  SnapsPerGame  \
# 0     1  Karlos Williams  BUF       RB      11          243          22.1
# 1     2    Joseph Randle  DAL       RB       6          145          24.2
# 2     3    David Johnson  ARI       RB      16          413          25.8
# 3     4      Todd Gurley  LAR       RB      13          456          35.1
# 4     5     Thomas Rawls  SEA       RB      13          289          22.2
#
#    SnapsPlayedPercentage  RushSnapPercentage  TargetSnapPercentage  \
# 0                   22.6                38.3                   5.8
# 1                   30.5                52.4                   6.9
# 2                   37.4                30.3                  13.8
# 3                   47.4                50.2                   5.7
# 4                   33.3                50.9                   3.8
#
#    TouchSnapPercentage  IntendedTouchSnapPercentage  FantasyPoints  \
# 0                 42.8                         44.0          113.3
# 1                 59.3                         59.3           64.1
# 2                 39.0                         44.1          173.8
# 3                 54.8                         55.9          187.4
# 4                 54.0                         54.7          118.6
#
#    FantasyPointSnapPercentage
# 0                        46.6
# 1                        44.2
# 2                        42.1
# 3                        41.1
# 4                        41.0

# %%
snap_count15.drop(['Rank', 'Played', 'SnapsPerGame', 'SnapsPlayedPercentage', 'RushSnapPercentage',
                   'TargetSnapPercentage', 'TouchSnapPercentage', 'IntendedTouchSnapPercentage',
                   'FantasyPoints', 'FantasyPointSnapPercentage'], axis=1, inplace=True)
snap_count15.head()
# Out:
#               Name Team Position  SnapsPlayed
# 0  Karlos Williams  BUF       RB          243
# 1    Joseph Randle  DAL       RB          145
# 2    David Johnson  ARI       RB          413
# 3      Todd Gurley  LAR       RB          456
# 4     Thomas Rawls  SEA       RB          289

# %%
rb16 = "../Snap Count/rb/rb2016.csv"

snap_count16 = pd.read_csv(rb16)
snap_count16.head()
# Out:
#    Rank               Name Team Position  Played  SnapsPlayed  SnapsPerGame  \
# 0     1       Ryan Mathews  PHI       RB      13          287          22.1
# 1     2      Tevin Coleman  ATL       RB      13          353          27.2
# 2     3  LeGarrette Blount   NE       RB      16          529          33.1
# 3     4    Ezekiel Elliott  DAL       RB      15          716          47.7
# 4     5       LeSean McCoy  BUF       RB      15          645          43.0
#
#    SnapsPlayedPercentage  RushSnapPercentage  TargetSnapPercentage  \
# 0                   25.3                54.0                   4.9
# 1                   33.9                33.4                  11.3
# 2                   47.2                56.5                   1.5
# 3                   67.5                45.0                   5.6
# 4                   60.6                36.3                   9.0
#
#    TouchSnapPercentage  IntendedTouchSnapPercentage  FantasyPoints  \
# 0                 58.5                         58.9          131.6
# 1                 42.2                         44.8          160.1
# 2                 57.8                         58.0          225.9
# 3                 49.4                         50.6          293.4
# 4                 44.2                         45.3          248.3
#
#    FantasyPointSnapPercentage
# 0                        45.9
# 1                        45.4
# 2                        42.7
# 3                        41.0
# 4                        38.5

# %%
snap_count16.drop(['Rank', 'Played', 'SnapsPerGame', 'SnapsPlayedPercentage', 'RushSnapPercentage',
                   'TargetSnapPercentage', 'TouchSnapPercentage', 'IntendedTouchSnapPercentage',
                   'FantasyPoints', 'FantasyPointSnapPercentage'], axis=1, inplace=True)
snap_count16.head()
# Out:
#                 Name Team Position  SnapsPlayed
# 0       Ryan Mathews  PHI       RB          287
# 1      Tevin Coleman  ATL       RB          353
# 2  LeGarrette Blount   NE       RB          529
# 3    Ezekiel Elliott  DAL       RB          716
# 4       LeSean McCoy  BUF       RB          645

# %%
rb17 = "../Snap Count/rb/rb2017.csv"

snap_count17 = pd.read_csv(rb17)
snap_count17.head()
# Out:
#    Rank          Name Team Position  Played  SnapsPlayed  SnapsPerGame  \
# 0     1  Alvin Kamara   NO       RB      16          464          29.0
# 1     2    Dion Lewis   NE       RB      16          404          25.2
# 2     3   Todd Gurley  LAR       RB      15          796          53.1
# 3     4  Alex Collins  BAL       RB      15          378          25.2
# 4     5   Mark Ingram   NO       RB      16          570          35.6
#
#    SnapsPlayedPercentage  RushSnapPercentage  TargetSnapPercentage  \
# 0                   44.7                25.9                  21.6
# 1                   35.4                44.6                   8.9
# 2                   76.5                35.1                  10.9
# 3                   37.1                56.1                   9.5
# 4                   54.9                40.4                  12.5
#
#    TouchSnapPercentage  IntendedTouchSnapPercentage  FantasyPoints  \
# 0                 43.3                         47.4          233.4
# 1                 52.5                         53.5          165.0
# 2                 43.1                         46.0          319.3
# 3                 62.2                         65.6          148.0
# 4                 50.5                         52.8          220.0
#
#    FantasyPointSnapPercentage
# 0                        50.3
# 1                        40.8
# 2                        40.1
# 3                        39.2
# 4                        38.6

# %%
snap_count17.drop(['Rank', 'Played', 'SnapsPerGame', 'SnapsPlayedPercentage', 'RushSnapPercentage',
                   'TargetSnapPercentage', 'TouchSnapPercentage', 'IntendedTouchSnapPercentage',
                   'FantasyPoints', 'FantasyPointSnapPercentage'], axis=1, inplace=True)
snap_count17.head()
# Out:
#            Name Team Position  SnapsPlayed
# 0  Alvin Kamara   NO       RB          464
# 1    Dion Lewis   NE       RB          404
# 2   Todd Gurley  LAR       RB          796
# 3  Alex Collins  BAL       RB          378
# 4   Mark Ingram   NO       RB          570

# %%
rb18 = "../Snap Count/rb/rb2018.csv"

snap_count18 = pd.read_csv(rb18)
snap_count18.head()
# Out:
#    Rank            Name Team Position  Played  SnapsPlayed  SnapsPerGame  \
# 0     1     Mark Ingram   NO       RB       1           36          36.0
# 1     2  Isaiah Crowell  NYJ       RB       6          158          26.3
# 2     3   Melvin Gordon  LAC       RB       6          270          45.0
# 3     3     Sony Michel   NE       RB       5          134          26.8
# 4     5   Austin Ekeler  LAC       RB       6          131          21.8
#
#    SnapsPlayedPercentage  RushSnapPercentage  TargetSnapPercentage  \
# 0                   54.5                44.4                   8.3
# 1                   42.0                44.3                   6.3
# 2                   70.5                33.7                  15.6
# 3                   39.8                67.9                   5.2
# 4                   34.2                31.3                  13.0
#
#    TouchSnapPercentage  IntendedTouchSnapPercentage  FantasyPoints  \
# 0                 50.0                         52.8           19.3
# 1                 49.4                         50.6           77.8
# 2                 44.8                         49.3          132.5
# 3                 70.1                         73.1           65.8
# 4                 42.0                         44.3           63.0
#
#    FantasyPointSnapPercentage
# 0                        53.6
# 1                        49.2
# 2                        49.1
# 3                        49.1
# 4                        48.1

# %%
snap_count18.drop(['Rank', 'Played', 'SnapsPerGame', 'SnapsPlayedPercentage', 'RushSnapPercentage',
                   'TargetSnapPercentage', 'TouchSnapPercentage', 'IntendedTouchSnapPercentage',
                   'FantasyPoints', 'FantasyPointSnapPercentage'], axis=1, inplace=True)
snap_count18.head()
# Out:
#              Name Team Position  SnapsPlayed
# 0     Mark Ingram   NO       RB           36
# 1  Isaiah Crowell  NYJ       RB          158
# 2   Melvin Gordon  LAC       RB          270
# 3     Sony Michel   NE       RB          134
# 4   Austin Ekeler  LAC       RB          131

# %%
# Combine the Data Frames for RB’s

rb_frames = [snap_count12, snap_count13, snap_count14, snap_count15, snap_count16, snap_count17, snap_count18]
rb_result = pd.concat(rb_frames)

# %%
rb_result.head()
# Out:
#               Name Team Position  SnapsPlayed
# 0      Andre Brown  NYG       RB          226
# 1  Adrian Peterson  MIN       RB          771
# 2       CJ Spiller  BUF       RB          569
# 3   Marshawn Lynch  SEA       RB          674
# 4    Stevan Ridley   NE       RB          550

# %%
rb_result.drop(['Team', 'Position'], axis=1, inplace=True)
rb_result.head()
# Out:
#               Name  SnapsPlayed
# 0      Andre Brown          226
# 1  Adrian Peterson          771
# 2       CJ Spiller          569
# 3   Marshawn Lynch          674
# 4    Stevan Ridley          550

# %%
rb_result.set_index('Name')
# Out:
#                      SnapsPlayed
# Name
# Andre Brown                  226
# Adrian Peterson              771
# CJ Spiller                   569
# Marshawn Lynch               674
# Stevan Ridley                550
# Jamaal Charles               577
# Alfred Morris                727
# Michael Turner               476
# Doug Martin                  821
# Darren Sproles               444
# Arian Foster                 830
# DeAngelo Williams            418
# Reggie Bush                  573
# Shonn Greene                 568
# Trent Richardson             702
# Willis McGahee               391
# Mikel Leshoure               529
# Frank Gore                   729
# Danny Woodhead               420
# James Starks                 125
# Ray Rice                     811
# Joique Bell                  382
# Knowshon Moreno              338
# Ahmad Bradshaw               600
# Maurice Jones-Drew           240
# Matt Forte                   693
# Pierre Thomas                384
# Fred Jackson                 331
# Felix Jones                  379
# Ryan Mathews                 403
# ...                          ...
# Chris Thompson               148
# Bilal Powell                 193
# Chris Ivory                  126
# Tevin Coleman                235
# Alfred Morris                147
# Ty Montgomery                144
# Javorius Allen               223
# Kenyan Drake                 223
# Leonard Fournette             45
# Christian McCaffrey          316
# Jalen Richard                149
# Nyheim Hines                 252
# Derrick Henry                139
# Latavius Murray              220
# Jordan Howard                213
# Alfred Blue                  187
# LeSean McCoy                 193
# Peyton Barber                200
# Dion Lewis                   226
# Duke Johnson                 198
# Lamar Miller                 247
# Jamaal Williams              202
# Dalvin Cook                  125
# Jordan Wilkins               136
# Devonta Freeman               67
# Marcus Murphy                 62
# Theo Riddick                 134
# Darren Sproles                29
# Kyle Juszczyk                263
# James Develin                144
#
# [482 rows x 1 columns]

# %%
rb_result.groupby(['Name']).sum().head()
# Out:
#                  SnapsPlayed
# Name
# Aaron Jones               87
# Adrian Peterson         2688
# Ahmad Bradshaw          1243
# Alex Collins             580
# Alex Green               347

# %%
rb_result.to_csv('Sum_RB_Snap_Count.csv')
