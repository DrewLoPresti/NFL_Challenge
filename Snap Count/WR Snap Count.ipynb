# %%
# Bring in snap counts for each year

import pandas as pd
import numpy as np

wr12 = "../Snap Count/wr/wr2012.csv"

snap_count12 = pd.read_csv(wr12)
snap_count12.head()
# Out:
#    Rank               Name Team Position  Played  SnapsPlayed  SnapsPerGame  \
# 0     1  Donte' Stallworth   NE       WR       1           20          20.0
# 1     2     Terrelle Pryor  OAK       WR       3           70          23.3
# 2     3   Michael Crabtree   SF       WR      16          675          42.2
# 3     4       Randall Cobb   GB       WR      15          635          42.3
# 4     5      Pierre Garcon  WAS       WR      10          395          39.5
#
#    SnapsPlayedPercentage  RushSnapPercentage  TargetSnapPercentage  \
# 0                   26.3                 0.0                  10.0
# 1                    6.5                14.3                   1.4
# 2                   67.2                 0.1                  18.7
# 3                   57.6                 1.6                  16.4
# 4                   38.2                 0.5                  17.0
#
#    TouchSnapPercentage  IntendedTouchSnapPercentage  FantasyPoints  \
# ...

# %%
# Clean up dataframes

snap_count12.drop(['Rank', 'Played', 'SnapsPerGame', 'SnapsPlayedPercentage', 'RushSnapPercentage',
                   'TargetSnapPercentage', 'TouchSnapPercentage', 'IntendedTouchSnapPercentage',
                   'FantasyPoints', 'FantasyPointSnapPercentage'], axis=1, inplace=True)
snap_count12.head()
# Out:
#                 Name Team Position  SnapsPlayed
# 0  Donte' Stallworth   NE       WR           20
# 1     Terrelle Pryor  OAK       WR           70
# 2   Michael Crabtree   SF       WR          675
# 3       Randall Cobb   GB       WR          635
# 4      Pierre Garcon  WAS       WR          395

# %%
wr13 = "../Snap Count/wr/wr2013.csv"

snap_count13 = pd.read_csv(wr13)
snap_count13.head()
# Out:
#    Rank                   Name Team Position  Played  SnapsPlayed  \
# 0     1           Marvin Jones  CIN       WR      16          542
# 1     2            Josh Gordon  CLE       WR      14          899
# 2     3         Calvin Johnson  DET       WR      14          892
# 3     4         Terrelle Pryor  OAK       WR      11          588
# 4     5  Cordarrelle Patterson  MIN       WR      16          436
#
#    SnapsPerGame  SnapsPlayedPercentage  RushSnapPercentage  \
# 0          33.9                   47.9                 1.5
# 1          64.2                   93.1                 0.6
# 2          63.7                   78.6                 0.0
# 3          53.5                   56.8                14.1
# 4          27.2                   41.9                 2.8
#
#    TargetSnapPercentage  TouchSnapPercentage  IntendedTouchSnapPercentage  \
# 0                  14.8                 10.9                         16.2
# ...

# %%
snap_count13.drop(['Rank', 'Played', 'SnapsPerGame', 'SnapsPlayedPercentage', 'RushSnapPercentage',
                   'TargetSnapPercentage', 'TouchSnapPercentage', 'IntendedTouchSnapPercentage',
                   'FantasyPoints', 'FantasyPointSnapPercentage'], axis=1, inplace=True)
snap_count13.head()
# Out:
#                     Name Team Position  SnapsPlayed
# 0           Marvin Jones  CIN       WR          542
# 1            Josh Gordon  CLE       WR          899
# 2         Calvin Johnson  DET       WR          892
# 3         Terrelle Pryor  OAK       WR          588
# 4  Cordarrelle Patterson  MIN       WR          436

# %%
wr14 = "../Snap Count/wr/wr2014.csv"

snap_count14 = pd.read_csv(wr14)
snap_count14.head()
# Out:
#    Rank              Name Team Position  Played  SnapsPlayed  SnapsPerGame  \
# 0     1   Martavis Bryant  PIT       WR      10          295          29.5
# 1     2  Odell Beckham Jr  NYG       WR      12          771          64.2
# 2     3        Dez Bryant  DAL       WR      16          897          56.1
# 3     4      Jordy Nelson   GB       WR      16          959          59.9
# 4     5     Antonio Brown  PIT       WR      16         1063          66.4
#
#    SnapsPlayedPercentage  RushSnapPercentage  TargetSnapPercentage  \
# 0                   26.5                 1.0                  16.3
# 1                   68.4                 0.9                  16.9
# 2                   84.7                 0.0                  15.2
# 3                   91.3                 0.0                  15.7
# 4                   95.5                 0.4                  17.0
#
#    TouchSnapPercentage  IntendedTouchSnapPercentage  FantasyPoints  \
# ...

# %%
snap_count14.drop(['Rank', 'Played', 'SnapsPerGame', 'SnapsPlayedPercentage', 'RushSnapPercentage',
                   'TargetSnapPercentage', 'TouchSnapPercentage', 'IntendedTouchSnapPercentage',
                   'FantasyPoints', 'FantasyPointSnapPercentage'], axis=1, inplace=True)
snap_count14.head()
# Out:
#                Name Team Position  SnapsPlayed
# 0   Martavis Bryant  PIT       WR          295
# 1  Odell Beckham Jr  NYG       WR          771
# 2        Dez Bryant  DAL       WR          897
# 3      Jordy Nelson   GB       WR          959
# 4     Antonio Brown  PIT       WR         1063

# %%
wr15 = "../Snap Count/wr/wr2015.csv"

snap_count15 = pd.read_csv(wr15)
snap_count15.head()
# Out:
#    Rank             Name Team Position  Played  SnapsPlayed  SnapsPerGame  \
# 0     1      Julio Jones  ATL       WR      16          932          58.2
# 1     2    Antonio Brown  PIT       WR      16         1002          62.6
# 2     3      Steve Smith  BAL       WR       7          349          49.9
# 3     4     Doug Baldwin  SEA       WR      16          801          50.1
# 4     5  Martavis Bryant  PIT       WR      11          511          46.5
#
#    SnapsPlayedPercentage  RushSnapPercentage  TargetSnapPercentage  \
# 0                   81.8                 0.0                  21.8
# 1                   93.2                 0.3                  19.3
# 2                   60.9                 0.0                  20.9
# 3                   74.0                 0.0                  12.9
# 4                   67.1                 1.0                  18.0
#
#    TouchSnapPercentage  IntendedTouchSnapPercentage  FantasyPoints  \
# ...

# %%
snap_count15.drop(['Rank', 'Played', 'SnapsPerGame', 'SnapsPlayedPercentage', 'RushSnapPercentage',
                   'TargetSnapPercentage', 'TouchSnapPercentage', 'IntendedTouchSnapPercentage',
                   'FantasyPoints', 'FantasyPointSnapPercentage'], axis=1, inplace=True)
snap_count15.head()
# Out:
#               Name Team Position  SnapsPlayed
# 0      Julio Jones  ATL       WR          932
# 1    Antonio Brown  PIT       WR         1002
# 2      Steve Smith  BAL       WR          349
# 3     Doug Baldwin  SEA       WR          801
# 4  Martavis Bryant  PIT       WR          511

# %%
wr16 = "../Snap Count/wr/wr2016.csv"

snap_count16 = pd.read_csv(wr16)
snap_count16.head()
# Out:
#    Rank             Name Team Position  Played  SnapsPlayed  SnapsPerGame  \
# 0     1      Tyreek Hill   KC       WR      16          418          26.1
# 1     2   Taylor Gabriel  ATL       WR      13          349          26.8
# 2     3  Marquess Wilson  CHI       WR       3           80          26.7
# 3     4      Julio Jones  ATL       WR      14          706          50.4
# 4     5     Keenan Allen  LAC       WR       1           27          27.0
#
#    SnapsPlayedPercentage  RushSnapPercentage  TargetSnapPercentage  \
# 0                   40.8                 5.7                  19.9
# 1                   33.6                 1.1                  14.3
# 2                    7.9                 0.0                  20.0
# 3                   67.9                 0.0                  18.3
# 4                    2.5                 0.0                  25.9
#
#    TouchSnapPercentage  IntendedTouchSnapPercentage  FantasyPoints  \
# ...

# %%
snap_count16.drop(['Rank', 'Played', 'SnapsPerGame', 'SnapsPlayedPercentage', 'RushSnapPercentage',
                   'TargetSnapPercentage', 'TouchSnapPercentage', 'IntendedTouchSnapPercentage',
                   'FantasyPoints', 'FantasyPointSnapPercentage'], axis=1, inplace=True)
snap_count16.head()
# Out:
#               Name Team Position  SnapsPlayed
# 0      Tyreek Hill   KC       WR          418
# 1   Taylor Gabriel  ATL       WR          349
# 2  Marquess Wilson  CHI       WR           80
# 3      Julio Jones  ATL       WR          706
# 4     Keenan Allen  LAC       WR           27

# %%
wr17 = "../Snap Count/wr/wr2017.csv"

snap_count17 = pd.read_csv(wr17)
snap_count17.head()
# Out:
#    Rank              Name Team Position  Played  SnapsPlayed  SnapsPerGame  \
# 0     1     Antonio Brown  PIT       WR      14          888          63.4
# 1     2  Odell Beckham Jr  NYG       WR       4          212          53.0
# 2     3       Julio Jones  ATL       WR      16          766          47.9
# 3     4       Tyreek Hill   KC       WR      15          779          51.9
# 4     5   DeAndre Hopkins  HOU       WR      15         1027          68.5
#
#    SnapsPlayedPercentage  RushSnapPercentage  TargetSnapPercentage  \
# 0                   80.1                 0.0                  18.4
# 1                   30.1                 0.5                  19.3
# 2                   74.7                 0.1                  19.3
# 3                   75.4                 2.2                  13.5
# 4                   93.2                 0.0                  16.9
#
#    TouchSnapPercentage  IntendedTouchSnapPercentage  FantasyPoints  \
# ...

# %%
snap_count17.drop(['Rank', 'Played', 'SnapsPerGame', 'SnapsPlayedPercentage', 'RushSnapPercentage',
                   'TargetSnapPercentage', 'TouchSnapPercentage', 'IntendedTouchSnapPercentage',
                   'FantasyPoints', 'FantasyPointSnapPercentage'], axis=1, inplace=True)
snap_count17.head()
# Out:
#                Name Team Position  SnapsPlayed
# 0     Antonio Brown  PIT       WR          888
# 1  Odell Beckham Jr  NYG       WR          212
# 2       Julio Jones  ATL       WR          766
# 3       Tyreek Hill   KC       WR          779
# 4   DeAndre Hopkins  HOU       WR         1027

# %%
wr18 = "../Snap Count/wr/wr2018.csv"

snap_count18 = pd.read_csv(wr18)
snap_count18.head()
# Out:
#    Rank            Name Team Position  Played  SnapsPlayed  SnapsPerGame  \
# 0     1  DeSean Jackson   TB       WR       5          170          34.0
# 1     2   Calvin Ridley  ATL       WR       6          215          35.8
# 2     3   Albert Wilson  MIA       WR       6          217          36.2
# 3     4     Tyreek Hill   KC       WR       6          347          57.8
# 4     5    Chris Godwin   TB       WR       5          180          36.0
#
#    SnapsPlayedPercentage  RushSnapPercentage  TargetSnapPercentage  \
# 0                   52.0                 0.6                  18.2
# 1                   52.4                 1.4                  13.5
# 2                   60.8                 2.8                  14.7
# 3                   88.5                 2.3                  14.7
# 4                   55.0                 0.0                  17.2
#
#    TouchSnapPercentage  IntendedTouchSnapPercentage  FantasyPoints  \
# ...

# %%
snap_count18.drop(['Rank', 'Played', 'SnapsPerGame', 'SnapsPlayedPercentage', 'RushSnapPercentage',
                   'TargetSnapPercentage', 'TouchSnapPercentage', 'IntendedTouchSnapPercentage',
                   'FantasyPoints', 'FantasyPointSnapPercentage'], axis=1, inplace=True)
snap_count18.head()
# Out:
#              Name Team Position  SnapsPlayed
# 0  DeSean Jackson   TB       WR          170
# 1   Calvin Ridley  ATL       WR          215
# 2   Albert Wilson  MIA       WR          217
# 3     Tyreek Hill   KC       WR          347
# 4    Chris Godwin   TB       WR          180

# %%
# Combine the Data Frames for WR’s

wr_frames = [snap_count12, snap_count13, snap_count14, snap_count15, snap_count16, snap_count17, snap_count18]
wr_result = pd.concat(wr_frames)

# %%
wr_result.head()
# Out:
#                 Name Team Position  SnapsPlayed
# 0  Donte' Stallworth   NE       WR           20
# 1     Terrelle Pryor  OAK       WR           70
# 2   Michael Crabtree   SF       WR          675
# 3       Randall Cobb   GB       WR          635
# 4      Pierre Garcon  WAS       WR          395

# %%
wr_result.drop(['Team', 'Position'], axis=1, inplace=True)
wr_result.head()
# Out:
#                 Name  SnapsPlayed
# 0  Donte' Stallworth           20
# 1     Terrelle Pryor           70
# 2   Michael Crabtree          675
# 3       Randall Cobb          635
# 4      Pierre Garcon          395

# %%
wr_result.set_index('Name')
# Out:
#                    SnapsPlayed
# Name
# Donte' Stallworth           20
# Terrelle Pryor              70
# Michael Crabtree           675
# Randall Cobb               635
# Pierre Garcon              395
# Percy Harvin               420
# Mohamed Sanu               204
# Santana Moss               454
# Lance Moore                608
# Dez Bryant                 920
# Danario Alexander          480
# Brandon Marshall           969
# Julio Jones                836
# Jarius Wright              206
# AJ Green                   960
# Cecil Shorts               656
# Marques Colston            831
# Jordy Nelson               595
# T.Y. Hilton                673
# Demaryius Thomas          1018
# Vincent Jackson            976
# Calvin Johnson            1151
# Andre Johnson              976
# Victor Cruz                904
# Mike Williams              832
# Jordan Norwood              76
# Roddy White                988
# Domenik Hixon              386
# Eric Decker               1047
# ...

# %%
wr_snap_total = wr_result.groupby(['Name']).sum()

# %%
wr_snap_total.to_csv('Sum_WR_Snap_Count.csv')

# %%
wr_snap_total
# Out:
#                    SnapsPlayed
# Name
# AJ Green                  5343
# AJ Jenkins                 247
# Aaron Dobson               759
# Ace Sanders                601
# Adam Humphries            1995
# Adam Thielen              2227
# Albert Wilson             1875
# Aldrick Robinson           845
# Alex Erickson              126
# Allen Hurns               3073
# Allen Robinson            2857
# Alshon Jeffery            4653
# Amari Cooper              2936
# Andre Holmes              1949
# Andre Johnson             3824
# Andre Roberts             2396
# Andrew Hawkins            2231
# Anquan Boldin             4226
# Anthony Miller             153
# Antonio Brown             5939
# Antonio Callaway           318
# Armon Binns                396
# Austin Carr                114
# Austin Pettis             1092
# Bennie Fowler              575
# Brad Smith                 314
# Brandin Cooks             3788
# Brandon Coleman           1446
# Brandon Gibson            1518
# ...
