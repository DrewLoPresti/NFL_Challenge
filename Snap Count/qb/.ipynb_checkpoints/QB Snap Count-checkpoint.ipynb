# %%
import pandas as pd
import numpy as np

file_to_load = "../qb/qb2012.csv"

purchase_data = pd.read_csv(file_to_load)
purchase_data
# Out:
#                  Player      Team Position  Total Snaps  Off Snaps  \
# 0            12-T.Brady        NE       QB         1213       1213
# 1          9-M.Stafford       DET       QB         1181       1181
# 2             12-A.Luck       IND       QB         1169       1169
# 3          18-P.Manning       DEN       QB         1111       1111
# 4            8-M.Schaub       HOU       QB         1106       1105
# 5             9-D.Brees        NO       QB         1095       1095
# 6              9-T.Romo       DAL       QB         1089       1089
# 7          12-A.Rodgers        GB       QB         1069       1069
# 8              2-M.Ryan       ATL       QB         1048       1048
# 9           5-J.Freeman        TB       QB         1037       1037
# 10         8-S.Bradford  LARM/STL       QB         1034       1034
# 11           7-C.Ponder       MIN       QB         1032       1032
# 12          14-A.Dalton       CIN       QB         1025       1025
# ...
